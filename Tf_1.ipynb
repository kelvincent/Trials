# %% [markdown]
# <a href="https://colab.research.google.com/github/kelvincent/Trials/blob/main/Tf_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is my first colib and ensoeflow examples

# %% [markdown]
# Public link

# %%
# !wget https://gist.githubusercontent.com/jwalsh/ce1dc0436aba5b7a5c9666f47fa5a380/raw/5ce3854392b43ff97907112d344fc008229b0445/titanic.csv
# Out:
# --2023-07-11 21:01:30--  https://gist.githubusercontent.com/jwalsh/ce1dc0436aba5b7a5c9666f47fa5a380/raw/5ce3854392b43ff97907112d344fc008229b0445/titanic.csv
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10239 (10.0K) [text/plain]
# Saving to: ‘titanic.csv’
#
# titanic.csv         100%[===================>]  10.00K  --.-KB/s    in 0s
#
# 2023-07-11 21:01:30 (57.6 MB/s) - ‘titanic.csv’ saved [10239/10239]

# %%
# !ls
# Out:
# sample_data  titanic.csv

# %%
import pandas as pd
pd.read_csv('titanic.csv', sep ='\t').head()
# Out:
#   PassengerId,Survived,Pclass,Lname,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked
# 0  1,0,3,Braund, Mr. Owen Harris,male,22,1,0,A/5 ...
# 1  2,1,1,Cumings, Mrs. John Bradley (Florence Bri...
# 2  3,1,3,Heikkinen, Miss. Laina,female,26,0,0,STO...
# 3  4,1,1,Futrelle, Mrs. Jacques Heath (Lily May P...
# 4  5,0,3,Allen, Mr. William Henry,male,35,0,0,373...
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_7036952598457853174 = autoviz.get_registered_df('df_7036952598457853174')
#
# def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   _, ax = plt.subplots(figsize=figsize)
#   bars = df[colname].value_counts()
#   plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
# ...

# %% [markdown]
# Google drive

# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %% [markdown]
# # Github Link

# %%
# !git clone https://github.com/stedy/Machine-learning-with-R-datasets.git
# Out:
# Cloning into 'Machine-learning-with-R-datasets'...
# remote: Enumerating objects: 50, done.
# remote: Total 50 (delta 0), reused 0 (delta 0), pack-reused 50
# Unpacking objects: 100% (50/50), 1014.03 KiB | 4.95 MiB/s, done.

# %% [markdown]
# Local Drive

# %%
pd.read_csv ('Dataset.csv', sep = '\t').head()
# Out:
#                                    id,label
# 0  Robert Downey Jr_87.jpg,Robert Downey Jr
# 1            Lisa Kudrow_64.jpg,Lisa Kudrow
# 2    Ellen Degeneres_34.jpg,Ellen Degeneres
# 3         Billie Eilish_3.jpg,Billie Eilish
# 4      Hrithik Roshan_35.jpg,Hrithik Roshan
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_2063890141372622474 = autoviz.get_registered_df('df_2063890141372622474')
#
# def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   _, ax = plt.subplots(figsize=figsize)
#   bars = df[colname].value_counts()
#   plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
# ...

# %% [markdown]
# ## How to write a system level command in Google colab
#
# ---

# %%
# !ls /bin
# Out:
# '['				      mpiCC
#  2to3-2.7			      mpicc.openmpi
#  2to3-3.10			      mpiCC.openmpi
#  7z				      mpic++.openmpi
#  7za				      mpicxx
#  7zr				      mpicxx.openmpi
#  aclocal			      mpiexec
#  aclocal-1.16			      mpiexec.openmpi
#  acyclic			      mpif77
#  add-apt-repository		      mpif77.openmpi
#  addpart			      mpif90
#  addr2line			      mpif90.openmpi
#  apropos			      mpifort
#  apt				      mpifort.openmpi
#  apt-add-repository		      mpirun
#  apt-cache			      mpirun.openmpi
#  apt-cdrom			      mtrace
#  apt-config			      mv
#  apt-extracttemplates		      mysql_config
#  apt-ftparchive			      namei
#  apt-get			      nawk
#  apt-key			      ncal
#  apt-mark			      nc-config
#  apt-sortpkgs			      ncurses5-config
#  ar				      ncurses6-config
#  arch				      ncursesw5-config
#  as				      ncursesw6-config
#  asan_symbolize			      neato
#  asan_symbolize-10		      neqn
#  assistant			      networkctl
#  autoconf			      newgrp
#  autoheader			      nice
# ...

# %%
# !date
# Out:
# Tue 11 Jul 2023 09:43:43 PM UTC

# %%
# !pwd
# Out:
# /content
